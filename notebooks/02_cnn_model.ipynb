# %%
import os
import json
import sys
import time
from pathlib import Path

import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import models, layers, optimizers
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, BatchNormalization
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.callbacks import TensorBoard, EarlyStopping, ReduceLROnPlateau

# Ensure project root is on sys.path so `utils` can be imported
cwd = Path.cwd()
if cwd.name.lower() == "notebooks":
    project_root = cwd.parent
elif cwd.name.lower() == "cifar10_project":
    project_root = cwd
elif (cwd / "cifar10_project").is_dir():
    project_root = cwd / "cifar10_project"
else:
    project_root = None

if project_root is not None and str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from utils.ml_utils import (
    evaluate_and_log_model,
    format_duration,
    predict_and_resolve_labels,
    compute_confusion_matrix,
    build_classification_report,
    plot_confusion_matrix_notebook01,
    plot_training_curves_notebook01,
)

gpus = tf.config.list_physical_devices("GPU")
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)
    print(f"GPU(s) detectada(s): {len(gpus)}")
else:
    print("Nenhuma GPU detectada. A correr em CPU.")
# Out:
# 2026-02-21 02:18:04.872145: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-21 02:18:04.909168: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-02-21 02:18:05.420967: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# GPU(s) detectada(s): 1
# 2026-02-21 02:18:06.135081: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-02-21 02:18:06.254413: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-02-21 02:18:06.254455: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
# Load the processed data (local project paths)
PROJECT_ROOT = os.getcwd()
if os.path.basename(PROJECT_ROOT).lower() == 'notebooks':
    PROJECT_ROOT = os.path.dirname(PROJECT_ROOT)
elif os.path.basename(PROJECT_ROOT).lower() != 'cifar10_project':
    candidate = os.path.join(PROJECT_ROOT, 'cifar10_project')
    if os.path.isdir(candidate):
        PROJECT_ROOT = candidate

DATA_DIR = os.path.join(PROJECT_ROOT, 'data')
PROCESSED_DIR = os.path.join(DATA_DIR, 'processed')
MODELS_DIR = os.path.join(PROJECT_ROOT, 'models')
REPORTS_DIR = os.path.join(PROJECT_ROOT, 'reports')
LOGS_ROOT = os.path.join(REPORTS_DIR, 'logs')

os.makedirs(MODELS_DIR, exist_ok=True)
os.makedirs(REPORTS_DIR, exist_ok=True)
os.makedirs(LOGS_ROOT, exist_ok=True)

data_path = os.path.join(PROCESSED_DIR, 'cifar10_processed.npz')
data = np.load(data_path)
x_train = data["x_train"]
y_train = data["y_train"]
x_val   = data["x_val"]
y_val   = data["y_val"]
x_test  = data["x_test"]
y_test  = data["y_test"]

print('Data path:', data_path)
# Out:
# Data path: /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/data/processed/cifar10_processed.npz

# %%
log_dir = os.path.join(LOGS_ROOT, pd.Timestamp.now().strftime("%Y%m%d-%H%M%S"))
os.makedirs(log_dir, exist_ok=True)

# %%
# Data augmentation for training
train_datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    zoom_range=0.1,
)

val_datagen = ImageDataGenerator()
test_datagen = ImageDataGenerator()

batch_size = 64

train_generator = train_datagen.flow(
    x_train, y_train,
    batch_size=batch_size,
    shuffle=True
)

val_generator = val_datagen.flow(
    x_val, y_val,
    batch_size=batch_size,
    shuffle=False
)

test_generator = test_datagen.flow(
    x_test, y_test,
    batch_size=batch_size,
    shuffle=False
)

# %% [markdown]
# # Creating, compiling and training the CNN base model

# %%
num_classes = 10

model = models.Sequential([
    # Block 1
    Input(shape=(32, 32, 3)),
    layers.Conv2D(32, (3, 3), activation="relu", padding="same"),
    layers.Conv2D(32, (3, 3), activation="relu", padding="same"),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),

    # Block 2
    layers.Conv2D(64, (3, 3), activation="relu", padding="same"),
    layers.Conv2D(64, (3, 3), activation="relu", padding="same"),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),

    # Block 3
    layers.Conv2D(128, (3, 3), activation="relu", padding="same"),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.4),

    # Classifier
    layers.Flatten(),
    layers.Dense(256, activation="relu"),
    layers.Dropout(0.5),
    layers.Dense(num_classes, activation="softmax"),
])

model.summary()
# Out:
# 2026-02-21 02:18:10.257502: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-02-21 02:18:10.257584: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-02-21 02:18:10.257605: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-02-21 02:18:10.371145: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-02-21 02:18:10.371216: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-02-21 02:18:10.371223: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2019] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2026-02-21 02:18:10.371246: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-02-21 02:18:10.371532: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5527 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Ti, pci bus id: 0000:01:00.0, compute capability: 8.9
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 666,538 (2.54 MB)
#  Trainable params: 666,538 (2.54 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
learning_rate = 1e-3

model.compile(
    optimizer=optimizers.Adam(learning_rate=learning_rate),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)

# %%
early_stopping = EarlyStopping(
    monitor="val_loss",
    patience=10,
    restore_best_weights=True,
    verbose=1,
)

lr_scheduler = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.5,
    patience=5,
    min_lr=1e-6,
    verbose=1,
)

# %%
epochs = 50

history = model.fit(
    train_generator,
    epochs=epochs,
    validation_data=val_generator,
    callbacks=[early_stopping, lr_scheduler],
    verbose=1,
)
# Out:
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1771640291.858758   28049 service.cc:145] XLA service 0x792ff4015d60 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1771640291.858796   28049 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 4060 Ti, Compute Capability 8.9
# 2026-02-21 02:18:11.888285: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2026-02-21 02:18:12.034714: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8907
#  16/625 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.0971 - loss: 2.3238
# I0000 00:00:1771640296.746448   28049 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - accuracy: 0.3288 - loss: 1.8080 - val_accuracy: 0.4499 - val_loss: 1.5098 - learning_rate: 0.0010
# Epoch 2/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.4697 - loss: 1.4461 - val_accuracy: 0.5176 - val_loss: 1.3405 - learning_rate: 0.0010
# Epoch 3/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.5300 - loss: 1.3087 - val_accuracy: 0.5942 - val_loss: 1.1228 - learning_rate: 0.0010
# Epoch 4/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.5592 - loss: 1.2239 - val_accuracy: 0.6211 - val_loss: 1.0562 - learning_rate: 0.0010
# Epoch 5/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.5906 - loss: 1.1570 - val_accuracy: 0.6347 - val_loss: 1.0201 - learning_rate: 0.0010
# Epoch 6/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.6090 - loss: 1.1049 - val_accuracy: 0.6653 - val_loss: 0.9425 - learning_rate: 0.0010
# Epoch 7/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.6243 - loss: 1.0666 - val_accuracy: 0.6824 - val_loss: 0.8824 - learning_rate: 0.0010
# Epoch 8/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.6370 - loss: 1.0279 - val_accuracy: 0.6688 - val_loss: 0.9693 - learning_rate: 0.0010
# Epoch 9/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.6477 - loss: 0.9994 - val_accuracy: 0.7065 - val_loss: 0.8345 - learning_rate: 0.0010
# Epoch 10/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.6556 - loss: 0.9810 - val_accuracy: 0.7291 - val_loss: 0.7563 - learning_rate: 0.0010
# Epoch 11/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.6686 - loss: 0.9487 - val_accuracy: 0.7143 - val_loss: 0.7981 - learning_rate: 0.0010
# Epoch 12/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.6729 - loss: 0.9341 - val_accuracy: 0.7051 - val_loss: 0.8349 - learning_rate: 0.0010
# Epoch 13/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.6773 - loss: 0.9236 - val_accuracy: 0.7333 - val_loss: 0.7397 - learning_rate: 0.0010
# Epoch 14/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.6797 - loss: 0.9109 - val_accuracy: 0.7441 - val_loss: 0.7209 - learning_rate: 0.0010
# Epoch 15/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.6902 - loss: 0.8924 - val_accuracy: 0.7251 - val_loss: 0.7646 - learning_rate: 0.0010
# Epoch 16/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.6904 - loss: 0.8830 - val_accuracy: 0.7361 - val_loss: 0.7547 - learning_rate: 0.0010
# Epoch 17/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.6934 - loss: 0.8825 - val_accuracy: 0.7368 - val_loss: 0.7332 - learning_rate: 0.0010
# Epoch 18/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.6936 - loss: 0.8681 - val_accuracy: 0.7119 - val_loss: 0.7928 - learning_rate: 0.0010
# Epoch 19/50
# 623/625 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7010 - loss: 0.8619
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.6994 - loss: 0.8666 - val_accuracy: 0.7248 - val_loss: 0.7815 - learning_rate: 0.0010
# Epoch 20/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.7159 - loss: 0.8129 - val_accuracy: 0.7444 - val_loss: 0.7217 - learning_rate: 5.0000e-04
# Epoch 21/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.7214 - loss: 0.7932 - val_accuracy: 0.7619 - val_loss: 0.6717 - learning_rate: 5.0000e-04
# Epoch 22/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.7272 - loss: 0.7838 - val_accuracy: 0.7597 - val_loss: 0.6753 - learning_rate: 5.0000e-04
# Epoch 23/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.7298 - loss: 0.7758 - val_accuracy: 0.7386 - val_loss: 0.7454 - learning_rate: 5.0000e-04
# Epoch 24/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.7317 - loss: 0.7705 - val_accuracy: 0.7595 - val_loss: 0.6675 - learning_rate: 5.0000e-04
# Epoch 25/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.7342 - loss: 0.7641 - val_accuracy: 0.7544 - val_loss: 0.6921 - learning_rate: 5.0000e-04
# Epoch 26/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.7354 - loss: 0.7613 - val_accuracy: 0.7481 - val_loss: 0.7189 - learning_rate: 5.0000e-04
# Epoch 27/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.7364 - loss: 0.7554 - val_accuracy: 0.7689 - val_loss: 0.6598 - learning_rate: 5.0000e-04
# Epoch 28/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.7374 - loss: 0.7548 - val_accuracy: 0.7607 - val_loss: 0.6709 - learning_rate: 5.0000e-04
# Epoch 29/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.7374 - loss: 0.7506 - val_accuracy: 0.7714 - val_loss: 0.6465 - learning_rate: 5.0000e-04
# Epoch 30/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.7380 - loss: 0.7483 - val_accuracy: 0.7520 - val_loss: 0.7083 - learning_rate: 5.0000e-04
# Epoch 31/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.7412 - loss: 0.7475 - val_accuracy: 0.7694 - val_loss: 0.6562 - learning_rate: 5.0000e-04
# Epoch 32/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.7452 - loss: 0.7344 - val_accuracy: 0.7834 - val_loss: 0.6078 - learning_rate: 5.0000e-04
# Epoch 33/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.7460 - loss: 0.7274 - val_accuracy: 0.7608 - val_loss: 0.6881 - learning_rate: 5.0000e-04
# Epoch 34/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.7475 - loss: 0.7251 - val_accuracy: 0.7878 - val_loss: 0.6040 - learning_rate: 5.0000e-04
# Epoch 35/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.7472 - loss: 0.7219 - val_accuracy: 0.7704 - val_loss: 0.6515 - learning_rate: 5.0000e-04
# Epoch 36/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.7519 - loss: 0.7163 - val_accuracy: 0.7846 - val_loss: 0.6200 - learning_rate: 5.0000e-04
# Epoch 37/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.7516 - loss: 0.7135 - val_accuracy: 0.7674 - val_loss: 0.6512 - learning_rate: 5.0000e-04
# Epoch 38/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.7547 - loss: 0.7155 - val_accuracy: 0.7887 - val_loss: 0.5977 - learning_rate: 5.0000e-04
# Epoch 39/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.7525 - loss: 0.7133 - val_accuracy: 0.7820 - val_loss: 0.6241 - learning_rate: 5.0000e-04
# Epoch 40/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.7529 - loss: 0.7086 - val_accuracy: 0.7918 - val_loss: 0.5841 - learning_rate: 5.0000e-04
# Epoch 41/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.7533 - loss: 0.7076 - val_accuracy: 0.7539 - val_loss: 0.7121 - learning_rate: 5.0000e-04
# Epoch 42/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.7560 - loss: 0.7027 - val_accuracy: 0.7869 - val_loss: 0.6005 - learning_rate: 5.0000e-04
# Epoch 43/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.7576 - loss: 0.7012 - val_accuracy: 0.7870 - val_loss: 0.6113 - learning_rate: 5.0000e-04
# Epoch 44/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.7595 - loss: 0.6934 - val_accuracy: 0.7774 - val_loss: 0.6395 - learning_rate: 5.0000e-04
# Epoch 45/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7619 - loss: 0.6927
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.7593 - loss: 0.6964 - val_accuracy: 0.7906 - val_loss: 0.6059 - learning_rate: 5.0000e-04
# Epoch 46/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.7685 - loss: 0.6651 - val_accuracy: 0.7955 - val_loss: 0.5824 - learning_rate: 2.5000e-04
# Epoch 47/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.7710 - loss: 0.6582 - val_accuracy: 0.8060 - val_loss: 0.5549 - learning_rate: 2.5000e-04
# Epoch 48/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.7733 - loss: 0.6547 - val_accuracy: 0.7970 - val_loss: 0.5745 - learning_rate: 2.5000e-04
# Epoch 49/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.7693 - loss: 0.6584 - val_accuracy: 0.7830 - val_loss: 0.6274 - learning_rate: 2.5000e-04
# Epoch 50/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.7746 - loss: 0.6500 - val_accuracy: 0.7954 - val_loss: 0.5880 - learning_rate: 2.5000e-04
# Restoring model weights from the end of the best epoch: 47.

# %%
test_loss, test_acc = model.evaluate(test_generator, verbose=0)
print(f"Test accuracy: {test_acc:.4f}")
# Out:
# Test accuracy: 0.8056

# %% [markdown]
# # Improvements

# %%
num_classes = 10

model = models.Sequential([
    # Block 1
    Input(shape=(32, 32, 3)),
    layers.Conv2D(32, (3, 3), padding="same"), layers.Activation("relu"), layers.BatchNormalization(),
    layers.Conv2D(32, (3, 3), padding="same"), layers.Activation("relu"), layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),

    # Block 2
    layers.Conv2D(64, (3, 3), padding="same"), layers.Activation("relu"), layers.BatchNormalization(),
    layers.Conv2D(64, (3, 3), padding="same"), layers.Activation("relu"), layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),

    # Block 3
    layers.Conv2D(128, (3, 3), padding="same"), layers.Activation("relu"), layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.4),

    # Classifier
    layers.Flatten(),
    layers.Dense(256, activation="relu"), layers.BatchNormalization(),
    layers.Dropout(0.5),
    layers.Dense(num_classes, activation="softmax"),
])

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_5 (Conv2D)               │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 16, 16, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 668,842 (2.55 MB)
#  Trainable params: 667,690 (2.55 MB)
#  Non-trainable params: 1,152 (4.50 KB)

# %%
model.compile(
    optimizer = optimizers.Adam(learning_rate=3e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-07, amsgrad=False, name="Adam"),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)

# %%
early_stopping = EarlyStopping(
    monitor="val_loss",
    patience=32,
    restore_best_weights=True,
    verbose=1,
)

lr_scheduler = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.5,
    patience=16,
    min_lr=1e-6,
    verbose=1,
)

tensorboard_cb = TensorBoard(
    log_dir=log_dir,
    histogram_freq=1,
    write_graph=True,
    profile_batch='100,110'
)
# Out:
# 2026-02-21 02:24:14.005403: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:104] Profiler session initializing.
# 2026-02-21 02:24:14.005437: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:119] Profiler session started.
# 2026-02-21 02:24:14.005460: I external/local_xla/xla/backends/profiler/gpu/cupti_tracer.cc:1239] Profiler found 1 GPUs
# 2026-02-21 02:24:14.031051: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:131] Profiler session tear down.
# 2026-02-21 02:24:14.047100: I external/local_xla/xla/backends/profiler/gpu/cupti_tracer.cc:1364] CUPTI activity buffer flushed

# %%
class ExperimentLogger(Callback):
    def __init__(self, log_file=os.path.join(DATA_DIR, 'experiments.csv'), params=None):
        super().__init__()
        self.log_file = log_file
        self.params = params or {}
        self.best_val_acc = 0
        self.best_epoch = 0
        
    def on_epoch_end(self, epoch, logs=None):
        val_acc = logs.get('val_accuracy')
        if val_acc > self.best_val_acc:
            self.best_val_acc = val_acc
            self.best_epoch = epoch
            
    def on_train_end(self, logs=None):
        row = {
            'timestamp': pd.Timestamp.now().isoformat(),
            'model_name': self.params.get('name', 'unknown'),
            'batch_size': self.params.get('batch_size', 64),
            'lr': self.params.get('lr', 0),
            'best_epoch': self.best_epoch,
            'best_val_acc': round(self.best_val_acc, 4),
            'test_acc': 0
        }
        
        df_new = pd.DataFrame([row])
        if os.path.exists(self.log_file):
            df_old = pd.read_csv(self.log_file)
            df = pd.concat([df_old, df_new], ignore_index=True)
        else:
            df = df_new
            
        df.to_csv(self.log_file, index=False)
        print(f"✅ SAVED: {self.best_val_acc:.4f} val_acc → {self.log_file}")

params = {
    'name': 'vgg_bn_fixed_order',
    'batch_size': 64,
    'lr': 3e-4,
    'bn_order': 'conv-relu-bn',
    'epochs': 100
}

exp_logger = ExperimentLogger(params=params)

# %%
train_start_time = time.time()

history = model.fit(
    train_generator,
    steps_per_epoch=len(x_train) // batch_size,
    validation_steps=len(x_val) // batch_size,
    epochs=100,
    validation_data=val_generator,
    callbacks=[early_stopping, lr_scheduler, exp_logger, tensorboard_cb],
    verbose=1
)

train_duration_sec = time.time() - train_start_time
print(f"Training time: {format_duration(train_duration_sec)} ({train_duration_sec:.2f} sec)")
# Out:
# Epoch 1/100
# 110/625 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.1551 - loss: 3.2093
# 2026-02-21 02:24:20.626299: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:104] Profiler session initializing.
# 2026-02-21 02:24:20.626331: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:119] Profiler session started.
# 2026-02-21 02:24:20.765877: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:70] Profiler session collecting data.
# 2026-02-21 02:24:20.788432: I external/local_xla/xla/backends/profiler/gpu/cupti_tracer.cc:1364] CUPTI activity buffer flushed
# 2026-02-21 02:24:20.799290: I external/local_xla/xla/backends/profiler/gpu/cupti_collector.cc:540]  GpuTracer has collected 2093 callback api events and 2072 activity events.
# 2026-02-21 02:24:20.801626: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:131] Profiler session tear down.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.3144 - loss: 2.2111 - val_accuracy: 0.4124 - val_loss: 1.6647 - learning_rate: 3.0000e-04
# Epoch 2/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.4243 - loss: 1.6538 - val_accuracy: 0.4466 - val_loss: 1.7381 - learning_rate: 3.0000e-04
# Epoch 3/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.4872 - loss: 1.4420 - val_accuracy: 0.5858 - val_loss: 1.1469 - learning_rate: 3.0000e-04
# Epoch 4/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.5373 - loss: 1.2864 - val_accuracy: 0.5468 - val_loss: 1.3275 - learning_rate: 3.0000e-04
# Epoch 5/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.5748 - loss: 1.1896 - val_accuracy: 0.6182 - val_loss: 1.0906 - learning_rate: 3.0000e-04
# Epoch 6/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.6028 - loss: 1.1118 - val_accuracy: 0.6131 - val_loss: 1.1126 - learning_rate: 3.0000e-04
# Epoch 7/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - accuracy: 0.6245 - loss: 1.0560 - val_accuracy: 0.6570 - val_loss: 0.9802 - learning_rate: 3.0000e-04
# Epoch 8/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.6446 - loss: 1.0047 - val_accuracy: 0.6530 - val_loss: 1.0093 - learning_rate: 3.0000e-04
# Epoch 9/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.6590 - loss: 0.9646 - val_accuracy: 0.6259 - val_loss: 1.1229 - learning_rate: 3.0000e-04
# Epoch 10/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.6714 - loss: 0.9288 - val_accuracy: 0.6728 - val_loss: 0.9384 - learning_rate: 3.0000e-04
# Epoch 11/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.6830 - loss: 0.9010 - val_accuracy: 0.6952 - val_loss: 0.8799 - learning_rate: 3.0000e-04
# Epoch 12/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.6938 - loss: 0.8718 - val_accuracy: 0.6931 - val_loss: 0.8679 - learning_rate: 3.0000e-04
# Epoch 13/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.7003 - loss: 0.8519 - val_accuracy: 0.7115 - val_loss: 0.8200 - learning_rate: 3.0000e-04
# Epoch 14/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.7083 - loss: 0.8331 - val_accuracy: 0.7505 - val_loss: 0.7160 - learning_rate: 3.0000e-04
# Epoch 15/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.7148 - loss: 0.8131 - val_accuracy: 0.7346 - val_loss: 0.7663 - learning_rate: 3.0000e-04
# Epoch 16/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.7217 - loss: 0.7960 - val_accuracy: 0.7511 - val_loss: 0.7098 - learning_rate: 3.0000e-04
# Epoch 17/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.7284 - loss: 0.7729 - val_accuracy: 0.7237 - val_loss: 0.7973 - learning_rate: 3.0000e-04
# Epoch 18/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.7310 - loss: 0.7648 - val_accuracy: 0.7199 - val_loss: 0.8098 - learning_rate: 3.0000e-04
# Epoch 19/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - accuracy: 0.7355 - loss: 0.7509 - val_accuracy: 0.7496 - val_loss: 0.7076 - learning_rate: 3.0000e-04
# Epoch 20/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.7402 - loss: 0.7394 - val_accuracy: 0.7537 - val_loss: 0.6998 - learning_rate: 3.0000e-04
# Epoch 21/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.7443 - loss: 0.7359 - val_accuracy: 0.7268 - val_loss: 0.8103 - learning_rate: 3.0000e-04
# Epoch 22/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.7505 - loss: 0.7198 - val_accuracy: 0.7748 - val_loss: 0.6535 - learning_rate: 3.0000e-04
# Epoch 23/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.7529 - loss: 0.7150 - val_accuracy: 0.7788 - val_loss: 0.6391 - learning_rate: 3.0000e-04
# Epoch 24/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.7594 - loss: 0.6949 - val_accuracy: 0.7771 - val_loss: 0.6417 - learning_rate: 3.0000e-04
# Epoch 25/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.7589 - loss: 0.6912 - val_accuracy: 0.8094 - val_loss: 0.5569 - learning_rate: 3.0000e-04
# Epoch 26/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.7631 - loss: 0.6878 - val_accuracy: 0.7570 - val_loss: 0.6995 - learning_rate: 3.0000e-04
# Epoch 27/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.7679 - loss: 0.6705 - val_accuracy: 0.7885 - val_loss: 0.6037 - learning_rate: 3.0000e-04
# Epoch 28/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.7679 - loss: 0.6696 - val_accuracy: 0.7583 - val_loss: 0.7081 - learning_rate: 3.0000e-04
# Epoch 29/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.7691 - loss: 0.6598 - val_accuracy: 0.7842 - val_loss: 0.6249 - learning_rate: 3.0000e-04
# Epoch 30/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.7780 - loss: 0.6520 - val_accuracy: 0.7708 - val_loss: 0.6653 - learning_rate: 3.0000e-04
# Epoch 31/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.7781 - loss: 0.6383 - val_accuracy: 0.7746 - val_loss: 0.6586 - learning_rate: 3.0000e-04
# Epoch 32/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.7764 - loss: 0.6460 - val_accuracy: 0.7865 - val_loss: 0.6221 - learning_rate: 3.0000e-04
# Epoch 33/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.7803 - loss: 0.6394 - val_accuracy: 0.8100 - val_loss: 0.5536 - learning_rate: 3.0000e-04
# Epoch 34/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.7825 - loss: 0.6327 - val_accuracy: 0.7628 - val_loss: 0.6938 - learning_rate: 3.0000e-04
# Epoch 35/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.7850 - loss: 0.6199 - val_accuracy: 0.7992 - val_loss: 0.5750 - learning_rate: 3.0000e-04
# Epoch 36/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.7834 - loss: 0.6240 - val_accuracy: 0.8073 - val_loss: 0.5611 - learning_rate: 3.0000e-04
# Epoch 37/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.7852 - loss: 0.6196 - val_accuracy: 0.8144 - val_loss: 0.5262 - learning_rate: 3.0000e-04
# Epoch 38/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.7895 - loss: 0.6085 - val_accuracy: 0.8239 - val_loss: 0.5018 - learning_rate: 3.0000e-04
# Epoch 39/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.7896 - loss: 0.6021 - val_accuracy: 0.8126 - val_loss: 0.5486 - learning_rate: 3.0000e-04
# Epoch 40/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.7923 - loss: 0.6018 - val_accuracy: 0.8010 - val_loss: 0.5634 - learning_rate: 3.0000e-04
# Epoch 41/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.7918 - loss: 0.6017 - val_accuracy: 0.8034 - val_loss: 0.5656 - learning_rate: 3.0000e-04
# Epoch 42/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.7973 - loss: 0.5890 - val_accuracy: 0.7991 - val_loss: 0.5837 - learning_rate: 3.0000e-04
# Epoch 43/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.7953 - loss: 0.5897 - val_accuracy: 0.8164 - val_loss: 0.5243 - learning_rate: 3.0000e-04
# Epoch 44/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.7982 - loss: 0.5845 - val_accuracy: 0.8236 - val_loss: 0.5042 - learning_rate: 3.0000e-04
# Epoch 45/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.7992 - loss: 0.5784 - val_accuracy: 0.7732 - val_loss: 0.6688 - learning_rate: 3.0000e-04
# Epoch 46/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.7990 - loss: 0.5776 - val_accuracy: 0.8188 - val_loss: 0.5183 - learning_rate: 3.0000e-04
# Epoch 47/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8015 - loss: 0.5762 - val_accuracy: 0.8190 - val_loss: 0.5263 - learning_rate: 3.0000e-04
# Epoch 48/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8026 - loss: 0.5696 - val_accuracy: 0.8344 - val_loss: 0.4759 - learning_rate: 3.0000e-04
# Epoch 49/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8014 - loss: 0.5759 - val_accuracy: 0.8299 - val_loss: 0.4859 - learning_rate: 3.0000e-04
# Epoch 50/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.8027 - loss: 0.5665 - val_accuracy: 0.8144 - val_loss: 0.5414 - learning_rate: 3.0000e-04
# Epoch 51/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8064 - loss: 0.5600 - val_accuracy: 0.8125 - val_loss: 0.5472 - learning_rate: 3.0000e-04
# Epoch 52/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8069 - loss: 0.5578 - val_accuracy: 0.7995 - val_loss: 0.6209 - learning_rate: 3.0000e-04
# Epoch 53/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.8068 - loss: 0.5569 - val_accuracy: 0.8328 - val_loss: 0.4841 - learning_rate: 3.0000e-04
# Epoch 54/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.8096 - loss: 0.5537 - val_accuracy: 0.8364 - val_loss: 0.4782 - learning_rate: 3.0000e-04
# Epoch 55/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8094 - loss: 0.5537 - val_accuracy: 0.8063 - val_loss: 0.5712 - learning_rate: 3.0000e-04
# Epoch 56/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8132 - loss: 0.5440 - val_accuracy: 0.8364 - val_loss: 0.4716 - learning_rate: 3.0000e-04
# Epoch 57/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8124 - loss: 0.5422 - val_accuracy: 0.8112 - val_loss: 0.5493 - learning_rate: 3.0000e-04
# Epoch 58/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.8124 - loss: 0.5395 - val_accuracy: 0.7919 - val_loss: 0.6028 - learning_rate: 3.0000e-04
# Epoch 59/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8143 - loss: 0.5365 - val_accuracy: 0.8218 - val_loss: 0.5336 - learning_rate: 3.0000e-04
# Epoch 60/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8148 - loss: 0.5373 - val_accuracy: 0.8371 - val_loss: 0.4709 - learning_rate: 3.0000e-04
# Epoch 61/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8169 - loss: 0.5325 - val_accuracy: 0.8445 - val_loss: 0.4490 - learning_rate: 3.0000e-04
# Epoch 62/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.8141 - loss: 0.5330 - val_accuracy: 0.8294 - val_loss: 0.5029 - learning_rate: 3.0000e-04
# Epoch 63/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8147 - loss: 0.5330 - val_accuracy: 0.8223 - val_loss: 0.5136 - learning_rate: 3.0000e-04
# Epoch 64/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8174 - loss: 0.5306 - val_accuracy: 0.8379 - val_loss: 0.4749 - learning_rate: 3.0000e-04
# Epoch 65/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8169 - loss: 0.5318 - val_accuracy: 0.8302 - val_loss: 0.4955 - learning_rate: 3.0000e-04
# Epoch 66/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.8178 - loss: 0.5275 - val_accuracy: 0.8508 - val_loss: 0.4359 - learning_rate: 3.0000e-04
# Epoch 67/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8199 - loss: 0.5203 - val_accuracy: 0.8389 - val_loss: 0.4803 - learning_rate: 3.0000e-04
# Epoch 68/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8206 - loss: 0.5263 - val_accuracy: 0.8301 - val_loss: 0.4955 - learning_rate: 3.0000e-04
# Epoch 69/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8181 - loss: 0.5199 - val_accuracy: 0.8268 - val_loss: 0.5079 - learning_rate: 3.0000e-04
# Epoch 70/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.8236 - loss: 0.5148 - val_accuracy: 0.8468 - val_loss: 0.4489 - learning_rate: 3.0000e-04
# Epoch 71/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8206 - loss: 0.5203 - val_accuracy: 0.8290 - val_loss: 0.5015 - learning_rate: 3.0000e-04
# Epoch 72/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8242 - loss: 0.5142 - val_accuracy: 0.8198 - val_loss: 0.5433 - learning_rate: 3.0000e-04
# Epoch 73/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8248 - loss: 0.5097 - val_accuracy: 0.8278 - val_loss: 0.5115 - learning_rate: 3.0000e-04
# Epoch 74/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.8270 - loss: 0.5035 - val_accuracy: 0.8448 - val_loss: 0.4574 - learning_rate: 3.0000e-04
# Epoch 75/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8237 - loss: 0.5112 - val_accuracy: 0.8261 - val_loss: 0.5048 - learning_rate: 3.0000e-04
# Epoch 76/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8262 - loss: 0.5041 - val_accuracy: 0.8326 - val_loss: 0.4883 - learning_rate: 3.0000e-04
# Epoch 77/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8285 - loss: 0.5001 - val_accuracy: 0.8287 - val_loss: 0.5085 - learning_rate: 3.0000e-04
# Epoch 78/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - accuracy: 0.8276 - loss: 0.4970 - val_accuracy: 0.8399 - val_loss: 0.4779 - learning_rate: 3.0000e-04
# Epoch 79/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8252 - loss: 0.5016 - val_accuracy: 0.8501 - val_loss: 0.4404 - learning_rate: 3.0000e-04
# Epoch 80/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8286 - loss: 0.5042 - val_accuracy: 0.8386 - val_loss: 0.4828 - learning_rate: 3.0000e-04
# Epoch 81/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8270 - loss: 0.4965 - val_accuracy: 0.8253 - val_loss: 0.5252 - learning_rate: 3.0000e-04
# Epoch 82/100
# 622/625 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8306 - loss: 0.4899
# Epoch 82: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.8275 - loss: 0.4975 - val_accuracy: 0.8123 - val_loss: 0.5643 - learning_rate: 3.0000e-04
# Epoch 83/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8348 - loss: 0.4805 - val_accuracy: 0.8425 - val_loss: 0.4731 - learning_rate: 1.5000e-04
# Epoch 84/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8356 - loss: 0.4780 - val_accuracy: 0.8359 - val_loss: 0.4814 - learning_rate: 1.5000e-04
# Epoch 85/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.8359 - loss: 0.4746 - val_accuracy: 0.8672 - val_loss: 0.3928 - learning_rate: 1.5000e-04
# Epoch 86/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8367 - loss: 0.4707 - val_accuracy: 0.8614 - val_loss: 0.4080 - learning_rate: 1.5000e-04
# Epoch 87/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8346 - loss: 0.4758 - val_accuracy: 0.8418 - val_loss: 0.4661 - learning_rate: 1.5000e-04
# Epoch 88/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8392 - loss: 0.4680 - val_accuracy: 0.8503 - val_loss: 0.4420 - learning_rate: 1.5000e-04
# Epoch 89/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.8376 - loss: 0.4699 - val_accuracy: 0.8365 - val_loss: 0.4841 - learning_rate: 1.5000e-04
# Epoch 90/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8404 - loss: 0.4610 - val_accuracy: 0.8488 - val_loss: 0.4494 - learning_rate: 1.5000e-04
# Epoch 91/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8401 - loss: 0.4596 - val_accuracy: 0.8405 - val_loss: 0.4676 - learning_rate: 1.5000e-04
# Epoch 92/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8391 - loss: 0.4635 - val_accuracy: 0.8467 - val_loss: 0.4549 - learning_rate: 1.5000e-04
# Epoch 93/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8383 - loss: 0.4615 - val_accuracy: 0.8578 - val_loss: 0.4181 - learning_rate: 1.5000e-04
# Epoch 94/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.8419 - loss: 0.4585 - val_accuracy: 0.8442 - val_loss: 0.4576 - learning_rate: 1.5000e-04
# Epoch 95/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8425 - loss: 0.4559 - val_accuracy: 0.8471 - val_loss: 0.4499 - learning_rate: 1.5000e-04
# Epoch 96/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8400 - loss: 0.4591 - val_accuracy: 0.8585 - val_loss: 0.4205 - learning_rate: 1.5000e-04
# Epoch 97/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8437 - loss: 0.4558 - val_accuracy: 0.8570 - val_loss: 0.4173 - learning_rate: 1.5000e-04
# Epoch 98/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.8410 - loss: 0.4558 - val_accuracy: 0.8549 - val_loss: 0.4333 - learning_rate: 1.5000e-04
# Epoch 99/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8433 - loss: 0.4529 - val_accuracy: 0.8456 - val_loss: 0.4610 - learning_rate: 1.5000e-04
# Epoch 100/100
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8428 - loss: 0.4582 - val_accuracy: 0.8471 - val_loss: 0.4560 - learning_rate: 1.5000e-04
# Restoring model weights from the end of the best epoch: 85.
# ✅ SAVED: 0.8672 val_acc → /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/data/experiments.csv
# Training time: 13 min 03 sec (783.49 sec)

# %%
test_loss, test_acc = model.evaluate(test_generator, verbose=0)
print(f"Test accuracy: {test_acc:.4f}")

# Update CSV with test_acc
log_path = os.path.join(DATA_DIR, 'experiments.csv')

if os.path.exists(log_path):
    df = pd.read_csv(log_path)
    if len(df) > 0:
        df.iloc[-1, df.columns.get_loc('test_acc')] = test_acc
        df.to_csv(log_path, index=False)
        print(f"✅ Updated CSV: test_acc={test_acc:.4f}")
    else:
        print("⚠️ CSV exists but is empty")
else:
    print("⚠️ experiments.csv don't exist")

print("Done!")
# Out:
# Test accuracy: 0.8583
# ✅ Updated CSV: test_acc=0.8583
# Done!
# /tmp/ipykernel_27896/4262134784.py:10: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.858299970626831' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[-1, df.columns.get_loc('test_acc')] = test_acc

# %%
# Detailed report using reusable utils
y_true, y_pred = predict_and_resolve_labels(model=model, data=test_generator, verbose=0)

print("Classification Report:")
print(build_classification_report(y_true, y_pred))

class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']
cm = compute_confusion_matrix(y_true, y_pred)
plot_confusion_matrix_notebook01(
    confusion=cm,
    class_names=class_names,
    title='Confusion Matrix (CNN Base)',
    save_path=os.path.join(REPORTS_DIR, 'confusion.png'),
)

plot_training_curves_notebook01(
    history=history,
    save_path=os.path.join(REPORTS_DIR, 'curves.png'),
)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.8673    0.8820    0.8746      1000
#            1     0.9478    0.9440    0.9459      1000
#            2     0.8633    0.7580    0.8072      1000
#            3     0.8329    0.6480    0.7289      1000
#            4     0.8284    0.8590    0.8434      1000
#            5     0.8366    0.7630    0.7981      1000
#            6     0.7285    0.9660    0.8306      1000
#            7     0.9161    0.8840    0.8997      1000
#            8     0.9222    0.9370    0.9296      1000
#            9     0.8763    0.9420    0.9080      1000
#
#     accuracy                         0.8583     10000
#    macro avg     0.8619    0.8583    0.8566     10000
# weighted avg     0.8619    0.8583    0.8566     10000

# %%
# Save model
model_path = os.path.join(MODELS_DIR, 'vgg_bn_best_85.keras')
model.save(model_path)
print("✅ Saved Model:", model_path)

# Quick test confirmation
test_loss, test_acc = model.evaluate(test_generator, verbose=0)
print(f"Confirm: Test acc = {test_acc:.4f}")

# Reusable experiment logging
performance_report_path = os.path.join(DATA_DIR, 'model_performance_report.csv')
row = evaluate_and_log_model(
    model=model,
    model_name='CNN - VGG-like Base',
    data=test_generator,
    csv_path=performance_report_path,
    history=history,
    train_time_sec=train_duration_sec if 'train_duration_sec' in globals() else None,
    average='macro',
    verbose=0,
    extra_fields={'test_loss': float(test_loss)},
)
print('Logged metrics:', row)
# Out:
# ✅ Saved Model: /mnt/c/Users/User/Documents/Bootcamp AI and Data Science/Linux/DataScience_ironhack/Week6/project/cifar10_project/models/vgg_bn_best_85.keras
# Confirm: Test acc = 0.8583
# Logged metrics: {'model_name': 'CNN - VGG-like Base', 'num_params': 668842, 'train_time_sec': 783.49, 'train_time': '13 min 03 sec', 'timestamp': '2026-02-21 02:37', 'accuracy': 0.8583, 'precision': 0.8619344373769906, 'recall': 0.8583000000000001, 'f1': 0.8565994247867446, 'support': 10000, 'final_accuracy': 0.8428249955177307, 'final_loss': 0.45824775099754333, 'final_val_accuracy': 0.8470553159713745, 'final_val_loss': 0.45602861046791077, 'final_learning_rate': 0.0001500000071246177, 'epochs_trained': 100, 'test_loss': 0.41463759541511536}
